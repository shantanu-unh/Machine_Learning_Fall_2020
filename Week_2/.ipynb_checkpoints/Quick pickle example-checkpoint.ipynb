# %%
# pip install py-postgresql
import postgresql
import pandas
import pickle

# %%
# Establish a connection to the database
# In an enterprise setting, we wouldn't put passwords in code.  Why?

db = postgresql.open("pq://new_haven_ds_read:new_haven_ds_secret_99@nhds.cwroivw0q1rc.us-east-1.rds.amazonaws.com/nhds")

# %%
# Let's create our SQL.....this is just a string
sql = 'select * from nhds.uci_adults'

# This is a prepared statement
ps = db.prepare(sql)

# Get results back and store in res variable
res = ps()

# %%
df = pandas.DataFrame(res, columns=ps.column_names)
df.tail()
# Out:
#        age      workclass  fnlwgt    education  educational_num  \
# 32556   27        Private  257302   Assoc-acdm               12
# 32557   40        Private  154374      HS-grad                9
# 32558   58        Private  151910      HS-grad                9
# 32559   22        Private  201490      HS-grad                9
# 32560   52   Self-emp-inc  287927      HS-grad                9
#
#             marital_status          occupation relationship    race   gender  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income  \
# 32556             0             0              38   United-States   <=50K
# 32557             0             0              40   United-States    >50K
# 32558             0             0              40   United-States   <=50K
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K
#
#           id
# 32556  32557
# 32557  32558
# 32558  32559
# 32559  32560
# 32560  32561

# %%
len(df)
# Out:
# 32561

# %%
df.to_pickle('df.pkl')

# %%
del(df)

# %%
# Let's prove that we have gotten rid of df: not defined
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0639c271669b> in <module>
#       1 # Let's prove that we have gotten rid of df: not defined
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
df = pandas.read_pickle('df.pkl')

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt    education  educational_num  \
# 32556   27        Private  257302   Assoc-acdm               12
# 32557   40        Private  154374      HS-grad                9
# 32558   58        Private  151910      HS-grad                9
# 32559   22        Private  201490      HS-grad                9
# 32560   52   Self-emp-inc  287927      HS-grad                9
#
#             marital_status          occupation relationship    race   gender  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income  \
# 32556             0             0              38   United-States   <=50K
# 32557             0             0              40   United-States    >50K
# 32558             0             0              40   United-States   <=50K
# 32559             0             0              20   United-States   <=50K
# 32560         15024             0              40   United-States    >50K
#
#           id
# 32556  32557
# 32557  32558
# 32558  32559
# 32559  32560
# 32560  32561

# %%
df.groupby('occupation')['fnlwgt'].mean()
# Out:
# occupation
#  ?                    188658.667390
#  Adm-clerical         192043.396286
#  Armed-Forces         215425.888889
#  Craft-repair         192132.599658
#  Exec-managerial      184414.012543
#  Farming-fishing      170190.176056
#  Handlers-cleaners    204391.006569
#  Machine-op-inspct    195040.877622
#  Other-service        188608.452200
#  Priv-house-serv      201107.523490
#  Prof-specialty       185296.613285
#  Protective-serv      202039.953775
#  Sales                190885.892055
#  Tech-support         192098.301724
#  Transport-moving     190366.355041
# Name: fnlwgt, dtype: float64

# %%
df['fnlwgt'].describe()
# Out:
# count    3.256100e+04
# mean     1.897784e+05
# std      1.055500e+05
# min      1.228500e+04
# 25%      1.178270e+05
# 50%      1.783560e+05
# 75%      2.370510e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64

# %%
df.corr()
# Out:
#                       age    fnlwgt  educational_num  capital_gain  \
# age              1.000000 -0.076646         0.036527      0.077674
# fnlwgt          -0.076646  1.000000        -0.043195      0.000432
# educational_num  0.036527 -0.043195         1.000000      0.122630
# capital_gain     0.077674  0.000432         0.122630      1.000000
# capital_loss     0.057775 -0.010252         0.079923     -0.031615
# hours_per_week   0.068756 -0.018768         0.148123      0.078409
# id               0.001286 -0.003153        -0.001079      0.001672
#
#                  capital_loss  hours_per_week        id
# age                  0.057775        0.068756  0.001286
# fnlwgt              -0.010252       -0.018768 -0.003153
# educational_num      0.079923        0.148123 -0.001079
# capital_gain        -0.031615        0.078409  0.001672
# capital_loss         1.000000        0.054256 -0.001188
# hours_per_week       0.054256        1.000000  0.000607
# id                  -0.001188        0.000607  1.000000
